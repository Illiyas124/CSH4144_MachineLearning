# %%
import numpy as np
import pandas as pd
df1 = pd.DataFrame(np.random.rand(10,4),columns =('col1','col2','col3','col4') )

# %%
print(df1)
# Out:
#        col1      col2      col3      col4
# 0  0.173977  0.086114  0.475902  0.242940
# 1  0.701764  0.868689  0.089876  0.200325
# 2  0.793277  0.581559  0.339138  0.796382
# 3  0.585328  0.444964  0.046997  0.829510
# 4  0.966446  0.876883  0.161983  0.026634
# 5  0.855022  0.628839  0.840091  0.122220
# 6  0.221038  0.732062  0.420571  0.963342
# 7  0.771370  0.835979  0.673805  0.000469
# 8  0.870910  0.231115  0.968486  0.910086
# 9  0.655905  0.697372  0.568135  0.385540

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df1.plot(subplots = True, figsize = (8,8))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df1.plot(kind ="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot(kind ="bar")#vertical bars
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind ="barh") #horizontal bars
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind ="box") #Boxplot  visual summary of datasets
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind ="bar", subplots = True, figsize = (8,8))
# Out:
# array([<AxesSubplot:title={'center':'col1'}>,
#        <AxesSubplot:title={'center':'col2'}>,
#        <AxesSubplot:title={'center':'col3'}>,
#        <AxesSubplot:title={'center':'col4'}>], dtype=object)

# %%
df1.plot(kind ="kde") #kernal density estimation plot
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1.plot(kind ="density")  #same as kde
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1.plot(kind ="area")
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind ="pie" ,y= 'col2')
# Out:
# <AxesSubplot:ylabel='col2'>

# %%
df1.plot(kind ="scatter" ,x = 'col1' ,  y = 'col2')
# Out:
# <AxesSubplot:xlabel='col1', ylabel='col2'>

# %%
df1.plot(kind ="hexbin" , x = 'col1' , y = 'col2')
# Out:
# <AxesSubplot:xlabel='col1', ylabel='col2'>

# %%
df1.plot.hexbin(x = 'col1', y = 'col2' , gridsize = 7)
# Out:
# <AxesSubplot:xlabel='col1', ylabel='col2'>

# %%
df1.plot(kind ="pie" ,y= 'col2',subplots = True, figsize=(8,8))
# Out:
# array([<AxesSubplot:ylabel='col2'>], dtype=object)
